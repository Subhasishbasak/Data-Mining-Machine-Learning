# %% [markdown]
# # Data Mining Machine Learning/Assignment_1/MDS201803

# %% [markdown]
# ### Description of the code to find frequent itemsets using Apriori algorithm

# %% [markdown]
# For each collection we are provided with 2 datasets viz. docword and vocab.<br>
# we follow these steps:
# - We store the 2 datasets using PANDAS dataframe as docword and vocab
# - From the docword dataframe we discard the first 3 header rows which cntain information about the dataset
# - Next we split the remaining portion of the docword dataset into 3 parts consisting docID, wordID and count
# - After that we create a dictionary to store the word_id's corresponding to each doc_id by iterating over the rows of the truncated dataset
# - Using this dictionary we contruct a array of arrays which stores the word_ids corresponding to each document
# - Now, to perform apriori we use the **"mlxtend"** library
# - the apriori function under mlxtend requires a Matrix and minimum support (user input F) as input. The matrix has the word_ids as columns and doc_ids as rows. Each element of the matrix stores either True or False according as the word_id is present in the doc_id. This matrix turns out to be a sparse matrix
# - Then we filter the frequent itemsets w.r.t the size of the set (user input K).
# - Next we create another dictionary to store the words corresponding to each word_id, using the vocab dataset.
# - Using this dictionary we map each word_id in the fequent itemset to the original word, which gives the required answer.

# %% [markdown]
# ### Parameters used

# %% [markdown]
# Our function takes 3 inputs:
#     - n : name of the collection
#     - K : size of the required frequent itemset
#     - F : minimum support
# Our function uses the following variabls:
#     - docword : Stores the docword dataset as pandas dataframe
#     - vocab : Stores the vocab dataset as pandas dataframe
#     - trunc : Stores the truncated docword dataset as pandas dataframe
#     - docword_splitted : Stores the splitted truncated docword dataset as pandas dataframe
#     - dict_1 : dictionary stores word ID's corresponding each document
#     - array : stores array of arrays containing all the inique word_id's of the documents
#     - Sp_matrix : stores the sparse matrix
#     - vocab_dict : dictionary stores words corresponding to word_id's

# %%
def Frequent_itemset(n,K,F):
    import pandas as pd
    import time
    from mlxtend.preprocessing import TransactionEncoder
    from mlxtend.frequent_patterns import apriori
    start = time.time()
    docword = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/bag-of-words/docword."+n+".txt.gz",header=None)
    vocab = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/bag-of-words/vocab."+n+".txt",header=None)
    vocab.columns = ["Word"] 
    trunc = docword[3:]        #truncates the Docword to remove the first 3 header line
    docword_splitted = pd.DataFrame(trunc[0].str.split(" ", n = 2, expand = True))    #Splits the truncated Docword into a data frame of 3 columns storing D,W,NNZ
    docword_splitted.columns = ['docID', 'wordID', 'count']      # Renames the column names of the splitted dataframe
    dict_1 = docword_splitted.groupby('docID')['wordID'].apply(list).to_dict()      #creates dictionary for document ID's to store word ID's corresponding each document
    array = list(dict_1.values())                             #creates an array of arrays containing all the inique word_id's of the documents
    Sp = TransactionEncoder()        
    Sp_array = Sp.fit(array).transform(array)
    Sp_matrix = pd.DataFrame(Sp_array, columns=Sp.columns_)   #creates the sparse matrix with columns as word_id & rows as doc_id
    ans = apriori(Sp_matrix, min_support=F,use_colnames=True)
    result=[]
    for i in ans['itemsets']:                    #filtering the frequent itemsets w.r.t set size
        if len(i)==K:
            result.append(list(i))
    vocab_dict = {}                              #creates dictionary to store words corresponding to word_id's
    for i in range(len(list(vocab["Word"]))):
        vocab_dict[i+1] = list(vocab["Word"])[i]        
    final = []
    for i in range(len(result)):                 #replacing word_id's by the words itself
        temp = []
        for j in range(K):
            temp.append(vocab_dict[int(result[i][j])])
        final.append(temp)
    end=time.time()
    print("The running time of the code is : ",end-start)    #prints the running time of the code
    return final

# %%
Frequent_itemset("enron",1,0.09)
# Out:
# The running time of the code is :  115.8614764213562
# [['friday'],
#  ['gas'],
#  ['give'],
#  ['going'],
#  ['group'],
#  ['help'],
#  ['hope'],
#  ['hour'],
#  ['houston'],
#  ['including'],
#  ['issue'],
#  ['issues'],
#  ['list'],
#  ['look'],
#  ['market'],
#  ['meeting'],
#  ['message'],
#  ['attached'],
#  ['monday'],
#  ['month'],
#  ['note'],
#  ['number'],
#  ['offer'],
#  ['office'],
#  ['order'],
#  ['part'],
#  ['phone'],
#  ['place'],
#  ['plan'],
#  ['point'],
#  ['power'],
#  ['price'],
#  ['problem'],
#  ['process'],
#  ['provide'],
#  ['receive'],
#  ['received'],
#  ['report'],
#  ['request'],
#  ['review'],
#  ['send'],
#  ['service'],
#  ['services'],
#  ['set'],
#  ['start'],
#  ['support'],
#  ['sure'],
#  ['team'],
#  ['thing'],
#  ['think'],
#  ['working'],
#  ['address'],
#  ['business'],
#  ['california'],
#  ['change'],
#  ['able'],
#  ['comment'],
#  ['company'],
#  ['contract'],
#  ['corp'],
#  ['cost'],
#  ['current'],
#  ['customer'],
#  ['date'],
#  ['deal'],
#  ['discuss'],
#  ['due'],
#  ['end'],
#  ['energy'],
#  ['find'],
#  ['forward'],
#  ['free']]

# %%
Frequent_itemset("nips",2,0.7)
# Out:
# The running time of the code is :  23.45193862915039
# [['set', 'system'],
#  ['data', 'set'],
#  ['set', 'abstract'],
#  ['function', 'set'],
#  ['set', 'information'],
#  ['input', 'set'],
#  ['set', 'introduction'],
#  ['learning', 'set'],
#  ['model', 'set'],
#  ['network', 'set'],
#  ['set', 'neural'],
#  ['number', 'set'],
#  ['problem', 'set'],
#  ['references', 'set'],
#  ['set', 'result'],
#  ['abstract', 'system'],
#  ['function', 'system'],
#  ['information', 'system'],
#  ['input', 'system'],
#  ['introduction', 'system'],
#  ['model', 'system'],
#  ['network', 'system'],
#  ['neural', 'system'],
#  ['number', 'system'],
#  ['problem', 'system'],
#  ['references', 'system'],
#  ['result', 'system'],
#  ['values', 'abstract'],
#  ['case', 'abstract'],
#  ['function', 'case'],
#  ['case', 'neural'],
#  ['references', 'case'],
#  ['case', 'result'],
#  ['data', 'abstract'],
#  ['function', 'data'],
#  ['data', 'neural'],
#  ['references', 'data'],
#  ['data', 'result'],
#  ['algorithm', 'abstract'],
#  ['references', 'algorithm'],
#  ['form', 'abstract'],
#  ['function', 'abstract'],
#  ['abstract', 'information'],
#  ['input', 'abstract'],
#  ['abstract', 'introduction'],
#  ['large', 'abstract'],
#  ['learning', 'abstract'],
#  ['model', 'abstract'],
#  ['network', 'abstract'],
#  ['abstract', 'neural'],
#  ['number', 'abstract'],
#  ['order', 'abstract'],
#  ['output', 'abstract'],
#  ['abstract', 'paper'],
#  ['abstract', 'parameter'],
#  ['point', 'abstract'],
#  ['problem', 'abstract'],
#  ['processing', 'abstract'],
#  ['references', 'abstract'],
#  ['abstract', 'result'],
#  ['function', 'information'],
#  ['function', 'input'],
#  ['function', 'introduction'],
#  ['learning', 'function'],
#  ['function', 'model'],
#  ['function', 'network'],
#  ['function', 'neural'],
#  ['function', 'number'],
#  ['problem', 'function'],
#  ['function', 'references'],
#  ['function', 'result'],
#  ['introduction', 'information'],
#  ['network', 'information'],
#  ['neural', 'information'],
#  ['number', 'information'],
#  ['references', 'information'],
#  ['information', 'result'],
#  ['input', 'introduction'],
#  ['input', 'network'],
#  ['input', 'neural'],
#  ['input', 'number'],
#  ['references', 'input'],
#  ['input', 'result'],
#  ['model', 'introduction'],
#  ['network', 'introduction'],
#  ['neural', 'introduction'],
#  ['number', 'introduction'],
#  ['problem', 'introduction'],
#  ['references', 'introduction'],
#  ['introduction', 'result'],
#  ['learning', 'neural'],
#  ['learning', 'references'],
#  ['learning', 'result'],
#  ['model', 'network'],
#  ['model', 'neural'],
#  ['model', 'number'],
#  ['references', 'model'],
#  ['model', 'result'],
#  ['network', 'neural'],
#  ['network', 'number'],
#  ['problem', 'network'],
#  ['references', 'network'],
#  ['network', 'result'],
#  ['number', 'neural'],
#  ['problem', 'neural'],
#  ['references', 'neural'],
#  ['neural', 'result'],
#  ['problem', 'number'],
#  ['references', 'number'],
#  ['number', 'result'],
#  ['references', 'order'],
#  ['order', 'result'],
#  ['references', 'paper'],
#  ['paper', 'result'],
#  ['problem', 'references'],
#  ['problem', 'result'],
#  ['references', 'result']]

# %%
Frequent_itemset("kos",3,0.1)
# Out:
# The running time of the code is :  19.206971883773804
# [['democratic', 'advertising', 'democrats'],
#  ['general', 'democratic', 'advertising'],
#  ['democratic', 'house', 'advertising'],
#  ['democratic', 'media', 'advertising'],
#  ['poll', 'democratic', 'advertising'],
#  ['democratic', 'advertising', 'primary'],
#  ['democratic', 'advertising', 'republicans'],
#  ['democratic', 'senate', 'advertising'],
#  ['democratic', 'bush', 'advertising'],
#  ['general', 'advertising', 'democrats'],
#  ['house', 'advertising', 'democrats'],
#  ['media', 'advertising', 'democrats'],
#  ['democrats', 'advertising', 'republicans'],
#  ['senate', 'advertising', 'democrats'],
#  ['bush', 'advertising', 'democrats'],
#  ['general', 'kerry', 'advertising'],
#  ['general', 'media', 'advertising'],
#  ['general', 'poll', 'advertising'],
#  ['general', 'advertising', 'polls'],
#  ['general', 'advertising', 'republicans'],
#  ['general', 'advertising', 'war'],
#  ['general', 'bush', 'advertising'],
#  ['bush', 'house', 'advertising'],
#  ['bush', 'kerry', 'advertising'],
#  ['poll', 'media', 'advertising'],
#  ['media', 'advertising', 'primary'],
#  ['senate', 'media', 'advertising'],
#  ['bush', 'media', 'advertising'],
#  ['poll', 'advertising', 'polls'],
#  ['poll', 'bush', 'advertising'],
#  ['bush', 'advertising', 'polls'],
#  ['bush', 'advertising', 'republicans'],
#  ['bush', 'senate', 'advertising'],
#  ['bush', 'advertising', 'war'],
#  ['democratic', 'bush', 'contact'],
#  ['general', 'bush', 'contact'],
#  ['contact', 'house', 'war'],
#  ['bush', 'contact', 'house'],
#  ['bush', 'contact', 'media'],
#  ['bush', 'contact', 'republicans'],
#  ['bush', 'contact', 'war'],
#  ['democratic', 'create', 'democrats'],
#  ['general', 'democratic', 'create'],
#  ['democratic', 'create', 'media'],
#  ['democratic', 'create', 'republicans'],
#  ['democratic', 'create', 'war'],
#  ['democratic', 'bush', 'create'],
#  ['create', 'house', 'democrats'],
#  ['create', 'republicans', 'democrats'],
#  ['democrats', 'create', 'war'],
#  ['bush', 'create', 'democrats'],
#  ['bush', 'economy', 'create'],
#  ['general', 'create', 'house'],
#  ['general', 'create', 'media'],
#  ['general', 'create', 'republicans'],
#  ['general', 'create', 'war'],
#  ['general', 'bush', 'create'],
#  ['house', 'create', 'republicans'],
#  ['house', 'create', 'senate'],
#  ['create', 'house', 'war'],
#  ['bush', 'create', 'house'],
#  ['bush', 'kerry', 'create'],
#  ['create', 'media', 'war'],
#  ['bush', 'create', 'media'],
#  ['poll', 'create', 'war'],
#  ['poll', 'bush', 'create'],
#  ['create', 'republicans', 'war'],
#  ['bush', 'create', 'republicans'],
#  ['bush', 'create', 'senate'],
#  ['bush', 'create', 'war'],
#  ['democratic', 'culture', 'democrats'],
#  ['democratic', 'bush', 'culture'],
#  ['bush', 'culture', 'democrats'],
#  ['bush', 'culture', 'republicans'],
#  ['democratic', 'kerry', 'dean'],
#  ['democratic', 'dean', 'primary'],
#  ['democratic', 'democrats', 'dem'],
#  ['general', 'democratic', 'dem'],
#  ['democratic', 'governor', 'dem'],
#  ['democratic', 'house', 'dem'],
#  ['democratic', 'kerry', 'dem'],
#  ['democratic', 'media', 'dem'],
#  ['democratic', 'november', 'dem'],
#  ['democratic', 'poll', 'dem'],
#  ['democratic', 'polls', 'dem'],
#  ['democratic', 'primary', 'dem'],
#  ['democratic', 'races', 'dem'],
#  ['democratic', 'republicans', 'dem'],
#  ['democratic', 'senate', 'dem'],
#  ['democratic', 'war', 'dem'],
#  ['democratic', 'bush', 'dem'],
#  ['general', 'democrats', 'dem'],
#  ['governor', 'democrats', 'dem'],
#  ['democrats', 'house', 'dem'],
#  ['democrats', 'kerry', 'dem'],
#  ['democrats', 'media', 'dem'],
#  ['poll', 'democrats', 'dem'],
#  ['democrats', 'polls', 'dem'],
#  ['democrats', 'primary', 'dem'],
#  ['democrats', 'races', 'dem'],
#  ['democrats', 'republicans', 'dem'],
#  ['democrats', 'senate', 'dem'],
#  ['war', 'democrats', 'dem'],
#  ['bush', 'democrats', 'dem'],
#  ['general', 'house', 'dem'],
#  ['general', 'kerry', 'dem'],
#  ['general', 'media', 'dem'],
#  ['general', 'november', 'dem'],
#  ['general', 'poll', 'dem'],
#  ['general', 'polls', 'dem'],
#  ['general', 'primary', 'dem'],
#  ['general', 'republicans', 'dem'],
#  ['general', 'senate', 'dem'],
#  ['general', 'war', 'dem'],
#  ['general', 'bush', 'dem'],
#  ['governor', 'bush', 'dem'],
#  ['media', 'house', 'dem'],
#  ['poll', 'house', 'dem'],
#  ['house', 'primary', 'dem'],
#  ['house', 'races', 'dem'],
#  ['house', 'republicans', 'dem'],
#  ['house', 'senate', 'dem'],
#  ['war', 'house', 'dem'],
#  ['bush', 'house', 'dem'],
#  ['poll', 'kerry', 'dem'],
#  ['kerry', 'polls', 'dem'],
#  ['kerry', 'primary', 'dem'],
#  ['bush', 'kerry', 'dem'],
#  ['poll', 'media', 'dem'],
#  ['media', 'polls', 'dem'],
#  ['media', 'primary', 'dem'],
#  ['media', 'republicans', 'dem'],
#  ['media', 'senate', 'dem'],
#  ['bush', 'media', 'dem'],
#  ['bush', 'november', 'dem'],
#  ['poll', 'polls', 'dem'],
#  ['poll', 'primary', 'dem'],
#  ['poll', 'republicans', 'dem'],
#  ['poll', 'senate', 'dem'],
#  ['war', 'poll', 'dem'],
#  ['poll', 'bush', 'dem'],
#  ['primary', 'polls', 'dem'],
#  ['republicans', 'polls', 'dem'],
#  ['bush', 'polls', 'dem'],
#  ['republicans', 'primary', 'dem'],
#  ['primary', 'senate', 'dem'],
#  ['bush', 'primary', 'dem'],
#  ['races', 'republicans', 'dem'],
#  ['bush', 'races', 'dem'],
#  ['republicans', 'senate', 'dem'],
#  ['war', 'republicans', 'dem'],
#  ['bush', 'republicans', 'dem'],
#  ['bush', 'senate', 'dem'],
#  ['war', 'bush', 'dem'],
#  ['democratic', 'economy', 'democrats'],
#  ['democratic', 'election', 'democrats'],
#  ['electoral', 'democratic', 'democrats'],
#  ['general', 'democratic', 'democrats'],
#  ['democratic', 'governor', 'democrats'],
#  ['democratic', 'house', 'democrats'],
#  ['democratic', 'kerry', 'democrats'],
#  ['democratic', 'labor', 'democrats'],
#  ['democratic', 'media', 'democrats'],
#  ['democratic', 'democrats', 'needed'],
#  ['democratic', 'november', 'democrats'],
#  ['poll', 'democratic', 'democrats'],
#  ['democratic', 'polls', 'democrats'],
#  ['democratic', 'primary', 'democrats'],
#  ['democratic', 'races', 'democrats'],
#  ['democratic', 'republicans', 'democrats'],
#  ['democratic', 'senate', 'democrats'],
#  ['democratic', 'democrats', 'split'],
#  ['democratic', 'straight', 'democrats'],
#  ['democratic', 'ticket', 'democrats'],
#  ['democratic', 'democrats', 'vote'],
#  ['democratic', 'voted', 'democrats'],
#  ['democratic', 'voter', 'democrats'],
#  ['democratic', 'democrats', 'war'],
#  ['democratic', 'bush', 'democrats'],
#  ['democratic', 'challenge', 'democrats'],
#  ['democratic', 'challenger', 'democrats'],
#  ['general', 'economy', 'democratic'],
#  ['democratic', 'economy', 'house'],
#  ['democratic', 'economy', 'kerry'],
#  ['democratic', 'economy', 'media'],
#  ['democratic', 'poll', 'economy'],
#  ['democratic', 'economy', 'polls'],
#  ['democratic', 'economy', 'primary'],
#  ['democratic', 'economy', 'republicans'],
#  ['democratic', 'economy', 'senate'],
#  ['democratic', 'economy', 'war'],
#  ['democratic', 'bush', 'economy'],
#  ['general', 'democratic', 'election'],
#  ['democratic', 'election', 'house'],
#  ['democratic', 'election', 'kerry'],
#  ['democratic', 'election', 'media'],
#  ['democratic', 'november', 'election'],
#  ['democratic', 'poll', 'election'],
#  ['democratic', 'election', 'polls'],
#  ['democratic', 'election', 'primary'],
#  ['democratic', 'election', 'republicans'],
#  ['democratic', 'election', 'senate'],
#  ['democratic', 'election', 'war'],
#  ['democratic', 'bush', 'election'],
#  ['general', 'electoral', 'democratic'],
#  ['democratic', 'electoral', 'house'],
#  ['democratic', 'electoral', 'media'],
#  ['poll', 'electoral', 'democratic'],
#  ['democratic', 'electoral', 'polls'],
#  ['democratic', 'electoral', 'primary'],
#  ['democratic', 'electoral', 'republicans'],
#  ['democratic', 'electoral', 'senate'],
#  ['democratic', 'bush', 'electoral'],
#  ['general', 'experience', 'democratic'],
#  ['democratic', 'bush', 'experience'],
#  ['general', 'democratic', 'governor'],
#  ['general', 'democratic', 'house'],
#  ['general', 'democratic', 'kerry'],
#  ['general', 'labor', 'democratic'],
#  ['general', 'democratic', 'media'],
#  ['general', 'democratic', 'needed'],
#  ['general', 'november', 'democratic'],
#  ['general', 'poll', 'democratic'],
#  ['general', 'democratic', 'polls'],
#  ['general', 'democratic', 'primary'],
#  ['general', 'democratic', 'races'],
#  ['general', 'democratic', 'republicans'],
#  ['general', 'democratic', 'senate'],
#  ['general', 'democratic', 'split'],
#  ['general', 'straight', 'democratic'],
#  ['general', 'ticket', 'democratic'],
#  ['general', 'democratic', 'vote'],
#  ['general', 'democratic', 'voted'],
#  ['general', 'democratic', 'voter'],
#  ['general', 'democratic', 'war'],
#  ['general', 'bush', 'democratic'],
#  ['general', 'challenge', 'democratic'],
#  ['general', 'democratic', 'challenger'],
#  ['democratic', 'house', 'governor'],
#  ['democratic', 'kerry', 'governor'],
#  ['democratic', 'media', 'governor'],
#  ['democratic', 'november', 'governor'],
#  ['democratic', 'poll', 'governor'],
#  ['democratic', 'polls', 'governor'],
#  ['democratic', 'primary', 'governor'],
#  ['democratic', 'races', 'governor'],
#  ['democratic', 'republicans', 'governor'],
#  ['democratic', 'senate', 'governor'],
#  ['democratic', 'governor', 'war'],
#  ['democratic', 'bush', 'governor'],
#  ['democratic', 'challenge', 'governor'],
#  ['democratic', 'kerry', 'house'],
#  ['democratic', 'labor', 'house'],
#  ['democratic', 'media', 'house'],
#  ['democratic', 'house', 'needed'],
#  ['democratic', 'november', 'house'],
#  ['democratic', 'poll', 'house'],
#  ['democratic', 'house', 'polls'],
#  ['democratic', 'house', 'primary'],
#  ['democratic', 'house', 'races'],
#  ['democratic', 'house', 'republicans'],
#  ['democratic', 'house', 'senate'],
#  ['democratic', 'house', 'split'],
#  ['democratic', 'ticket', 'house'],
#  ['democratic', 'house', 'voted'],
#  ['democratic', 'voter', 'house'],
#  ['democratic', 'house', 'war'],
#  ['democratic', 'bush', 'house'],
#  ['democratic', 'challenge', 'house'],
#  ['democratic', 'challenger', 'house'],
#  ['democratic', 'challengers', 'house'],
#  ['democratic', 'lead', 'kerry'],
#  ['democratic', 'kerry', 'media'],
#  ['democratic', 'november', 'kerry'],
#  ['democratic', 'poll', 'kerry'],
#  ['democratic', 'kerry', 'polls'],
#  ['democratic', 'kerry', 'primary'],
#  ['democratic', 'kerry', 'races'],
#  ['democratic', 'kerry', 'republicans'],
#  ['democratic', 'kerry', 'senate'],
#  ['democratic', 'kerry', 'vote'],
#  ['democratic', 'kerry', 'voted'],
#  ['democratic', 'kerry', 'voter'],
#  ['democratic', 'kerry', 'war'],
#  ['democratic', 'bush', 'kerry'],
#  ['democratic', 'labor', 'media'],
#  ['democratic', 'labor', 'november'],
#  ['democratic', 'poll', 'labor'],
#  ['democratic', 'labor', 'primary'],
#  ['democratic', 'labor', 'republicans'],
#  ['democratic', 'labor', 'senate'],
#  ['democratic', 'labor', 'war'],
#  ['democratic', 'bush', 'labor'],
#  ['democratic', 'media', 'needed'],
#  ['democratic', 'november', 'media'],
#  ['democratic', 'poll', 'media'],
#  ['democratic', 'media', 'polls'],
#  ['democratic', 'media', 'primary'],
#  ['democratic', 'media', 'races'],
#  ['democratic', 'media', 'republicans'],
#  ['democratic', 'media', 'senate'],
#  ['democratic', 'media', 'voted'],
#  ['democratic', 'voter', 'media'],
#  ['democratic', 'media', 'war'],
#  ['democratic', 'bush', 'media'],
#  ['democratic', 'challenge', 'media'],
#  ['democratic', 'poll', 'needed'],
#  ['democratic', 'polls', 'needed'],
#  ['democratic', 'primary', 'needed'],
#  ['democratic', 'republicans', 'needed'],
#  ['democratic', 'senate', 'needed'],
#  ['war', 'democratic', 'needed'],
#  ['democratic', 'bush', 'needed'],
#  ['democratic', 'poll', 'november'],
#  ['democratic', 'november', 'polls'],
#  ['democratic', 'november', 'primary'],
#  ['democratic', 'november', 'races'],
#  ['democratic', 'november', 'republicans'],
#  ['democratic', 'november', 'senate'],
#  ['democratic', 'november', 'voter'],
#  ['democratic', 'november', 'war'],
#  ['democratic', 'bush', 'november'],
#  ['democratic', 'poll', 'polls'],
#  ['democratic', 'poll', 'primary'],
#  ['democratic', 'poll', 'races'],
#  ['democratic', 'poll', 'republicans'],
#  ['democratic', 'poll', 'senate'],
#  ['democratic', 'poll', 'split'],
#  ['democratic', 'poll', 'ticket'],
#  ['democratic', 'poll', 'vote'],
#  ['democratic', 'poll', 'voted'],
#  ['democratic', 'poll', 'voter'],
#  ['democratic', 'poll', 'war'],
#  ['democratic', 'bush', 'poll'],
#  ['democratic', 'poll', 'challenge'],
#  ['democratic', 'poll', 'challenger'],
#  ['democratic', 'challengers', 'poll'],
#  ['democratic', 'polls', 'primary'],
#  ['democratic', 'races', 'polls'],
#  ['democratic', 'polls', 'republicans'],
#  ['democratic', 'senate', 'polls'],
#  ['democratic', 'voted', 'polls'],
#  ['democratic', 'voter', 'polls'],
#  ['democratic', 'polls', 'war'],
#  ['democratic', 'bush', 'polls'],
#  ['democratic', 'challenge', 'polls'],
#  ['democratic', 'challenger', 'polls'],
#  ['democratic', 'bush', 'president'],
#  ['democratic', 'races', 'primary'],
#  ['democratic', 'primary', 'republicans'],
#  ['democratic', 'scoop', 'primary'],
#  ['democratic', 'senate', 'primary'],
#  ['democratic', 'primary', 'split'],
#  ['democratic', 'ticket', 'primary'],
#  ['democratic', 'primary', 'vote'],
#  ['democratic', 'voted', 'primary'],
#  ['democratic', 'voter', 'primary'],
#  ['democratic', 'primary', 'war'],
#  ['democratic', 'bush', 'primary'],
#  ['democratic', 'challenge', 'primary'],
#  ['democratic', 'challenger', 'primary'],
#  ['democratic', 'challengers', 'primary'],
#  ['democratic', 'races', 'republicans'],
#  ['democratic', 'senate', 'races'],
#  ['democratic', 'races', 'war'],
#  ['democratic', 'bush', 'races'],
#  ['democratic', 'challenger', 'races'],
#  ['democratic', 'senate', 'republicans'],
#  ['democratic', 'ticket', 'republicans'],
#  ['democratic', 'republicans', 'vote'],
#  ['democratic', 'voted', 'republicans'],
#  ['democratic', 'voter', 'republicans'],
#  ['democratic', 'republicans', 'war'],
#  ['democratic', 'bush', 'republicans'],
#  ['democratic', 'challenge', 'republicans'],
#  ['democratic', 'challenger', 'republicans'],
#  ['democratic', 'ticket', 'senate'],
#  ['democratic', 'senate', 'voted'],
#  ['democratic', 'voter', 'senate'],
#  ['democratic', 'senate', 'war'],
#  ['democratic', 'bush', 'senate'],
#  ['democratic', 'challenge', 'senate'],
#  ['democratic', 'challenger', 'senate'],
#  ['war', 'democratic', 'split'],
#  ['democratic', 'bush', 'split'],
#  ['democratic', 'bush', 'straight'],
#  ['democratic', 'bush', 'ticket'],
#  ['democratic', 'bush', 'vote'],
#  ['democratic', 'voted', 'war'],
#  ['democratic', 'bush', 'voted'],
#  ['democratic', 'voter', 'war'],
#  ['democratic', 'bush', 'voter'],
#  ['democratic', 'bush', 'war'],
#  ['democratic', 'challenge', 'war'],
#  ['democratic', 'challenger', 'war'],
#  ['democratic', 'bush', 'campaign'],
#  ['democratic', 'bush', 'challenge'],
#  ['democratic', 'bush', 'challenger'],
#  ['democratic', 'challengers', 'bush'],
#  ['general', 'economy', 'democrats'],
#  ['economy', 'house', 'democrats'],
#  ['economy', 'kerry', 'democrats'],
#  ['economy', 'media', 'democrats'],
#  ['poll', 'economy', 'democrats'],
#  ['economy', 'polls', 'democrats'],
#  ['economy', 'republicans', 'democrats'],
#  ['economy', 'senate', 'democrats'],
#  ['democrats', 'economy', 'war'],
#  ['bush', 'economy', 'democrats'],
#  ['general', 'election', 'democrats'],
#  ['election', 'house', 'democrats'],
#  ['kerry', 'election', 'democrats'],
#  ['election', 'media', 'democrats'],
#  ['november', 'election', 'democrats'],
#  ['poll', 'election', 'democrats'],
#  ['election', 'polls', 'democrats'],
#  ['election', 'primary', 'democrats'],
#  ['election', 'republicans', 'democrats'],
#  ['election', 'senate', 'democrats'],
#  ['democrats', 'election', 'war'],
#  ['bush', 'election', 'democrats'],
#  ['general', 'electoral', 'democrats'],
#  ['electoral', 'house', 'democrats'],
#  ['poll', 'electoral', 'democrats'],
#  ['electoral', 'republicans', 'democrats'],
#  ['electoral', 'senate', 'democrats'],
#  ['electoral', 'democrats', 'war'],
#  ['electoral', 'bush', 'democrats'],
#  ['general', 'governor', 'democrats'],
#  ['general', 'house', 'democrats'],
#  ['general', 'kerry', 'democrats'],
#  ['general', 'media', 'democrats'],
#  ['general', 'democrats', 'needed'],
#  ['general', 'november', 'democrats'],
#  ['general', 'poll', 'democrats'],
#  ['general', 'polls', 'democrats'],
#  ['general', 'primary', 'democrats'],
#  ['general', 'races', 'democrats'],
#  ['general', 'republicans', 'democrats'],
#  ['general', 'senate', 'democrats'],
#  ['general', 'democrats', 'split'],
#  ['general', 'ticket', 'democrats'],
#  ['general', 'democrats', 'vote'],
#  ['general', 'voted', 'democrats'],
#  ['general', 'voter', 'democrats'],
#  ['general', 'democrats', 'war'],
#  ['general', 'bush', 'democrats'],
#  ['general', 'challenge', 'democrats'],
#  ['governor', 'house', 'democrats'],
#  ['governor', 'kerry', 'democrats'],
#  ['governor', 'media', 'democrats'],
#  ['governor', 'november', 'democrats'],
#  ['poll', 'governor', 'democrats'],
#  ['governor', 'polls', 'democrats'],
#  ['governor', 'primary', 'democrats'],
#  ['governor', 'races', 'democrats'],
#  ['governor', 'republicans', 'democrats'],
#  ['governor', 'senate', 'democrats'],
#  ['governor', 'democrats', 'war'],
#  ['governor', 'bush', 'democrats'],
#  ['governor', 'challenge', 'democrats'],
#  ['kerry', 'house', 'democrats'],
#  ['labor', 'house', 'democrats'],
#  ['media', 'house', 'democrats'],
#  ['democrats', 'house', 'needed'],
#  ['november', 'house', 'democrats'],
#  ['poll', 'house', 'democrats'],
#  ['house', 'polls', 'democrats'],
#  ['house', 'primary', 'democrats'],
#  ['house', 'races', 'democrats'],
#  ['house', 'republicans', 'democrats'],
#  ['house', 'senate', 'democrats'],
#  ['ticket', 'house', 'democrats'],
#  ['house', 'voted', 'democrats'],
#  ['voter', 'house', 'democrats'],
#  ['democrats', 'house', 'war'],
#  ['bush', 'house', 'democrats'],
#  ['challenge', 'house', 'democrats'],
#  ['challenger', 'house', 'democrats'],
#  ['kerry', 'media', 'democrats'],
#  ['kerry', 'november', 'democrats'],
#  ['poll', 'kerry', 'democrats'],
#  ['kerry', 'polls', 'democrats'],
#  ['kerry', 'primary', 'democrats'],
#  ['kerry', 'races', 'democrats'],
#  ['kerry', 'republicans', 'democrats'],
#  ['kerry', 'senate', 'democrats'],
#  ['democrats', 'kerry', 'vote'],
#  ['kerry', 'voter', 'democrats'],
#  ['democrats', 'kerry', 'war'],
#  ['bush', 'kerry', 'democrats'],
#  ['labor', 'media', 'democrats'],
#  ['labor', 'republicans', 'democrats'],
#  ['labor', 'senate', 'democrats'],
#  ['labor', 'democrats', 'war'],
#  ['bush', 'labor', 'democrats'],
#  ['democrats', 'media', 'needed'],
#  ['november', 'media', 'democrats'],
#  ['poll', 'media', 'democrats'],
#  ['media', 'polls', 'democrats'],
#  ['media', 'primary', 'democrats'],
#  ['media', 'races', 'democrats'],
#  ['media', 'republicans', 'democrats'],
#  ['media', 'senate', 'democrats'],
#  ['ticket', 'media', 'democrats'],
#  ['media', 'voted', 'democrats'],
#  ['voter', 'media', 'democrats'],
#  ['democrats', 'media', 'war'],
#  ['bush', 'media', 'democrats'],
#  ['democrats', 'republicans', 'needed'],
#  ['war', 'democrats', 'needed'],
#  ['bush', 'democrats', 'needed'],
#  ['poll', 'november', 'democrats'],
#  ['november', 'polls', 'democrats'],
#  ['november', 'primary', 'democrats'],
#  ['november', 'races', 'democrats'],
#  ['november', 'republicans', 'democrats'],
#  ['november', 'senate', 'democrats'],
#  ['november', 'voter', 'democrats'],
#  ['democrats', 'november', 'war'],
#  ['bush', 'november', 'democrats'],
#  ['poll', 'polls', 'democrats'],
#  ['poll', 'primary', 'democrats'],
#  ['poll', 'races', 'democrats'],
#  ['poll', 'republicans', 'democrats'],
#  ['poll', 'senate', 'democrats'],
#  ['poll', 'democrats', 'split'],
#  ['poll', 'ticket', 'democrats'],
#  ['poll', 'voted', 'democrats'],
#  ['poll', 'voter', 'democrats'],
#  ['poll', 'democrats', 'war'],
#  ['poll', 'bush', 'democrats'],
#  ['poll', 'challenger', 'democrats'],
#  ['democrats', 'polls', 'primary'],
#  ['races', 'polls', 'democrats'],
#  ['democrats', 'polls', 'republicans'],
#  ['senate', 'polls', 'democrats'],
#  ['voted', 'polls', 'democrats'],
#  ['voter', 'polls', 'democrats'],
#  ['democrats', 'polls', 'war'],
#  ['bush', 'polls', 'democrats'],
#  ['democrats', 'races', 'primary'],
#  ['republicans', 'primary', 'democrats'],
#  ['democrats', 'senate', 'primary'],
#  ['ticket', 'primary', 'democrats'],
#  ['democrats', 'voted', 'primary'],
#  ['democrats', 'primary', 'war'],
#  ['bush', 'primary', 'democrats'],
#  ['challenge', 'primary', 'democrats'],
#  ['challenger', 'primary', 'democrats'],
#  ['democrats', 'races', 'republicans'],
#  ['senate', 'races', 'democrats'],
#  ['democrats', 'races', 'war'],
#  ['bush', 'races', 'democrats'],
#  ['democrats', 'senate', 'republicans'],
#  ['democrats', 'republicans', 'split'],
#  ['ticket', 'republicans', 'democrats'],
#  ['democrats', 'republicans', 'vote'],
#  ['democrats', 'voted', 'republicans'],
#  ['voter', 'republicans', 'democrats'],
#  ['democrats', 'republicans', 'war'],
#  ['bush', 'republicans', 'democrats'],
#  ['challenge', 'republicans', 'democrats'],
#  ['challenger', 'republicans', 'democrats'],
#  ['senate', 'voted', 'democrats'],
#  ['voter', 'senate', 'democrats'],
#  ['democrats', 'senate', 'war'],
#  ['bush', 'senate', 'democrats'],
#  ['challenge', 'senate', 'democrats'],
#  ['bush', 'democrats', 'split'],
#  ['bush', 'straight', 'democrats'],
#  ['bush', 'ticket', 'democrats'],
#  ['bush', 'democrats', 'vote'],
#  ['democrats', 'voted', 'war'],
#  ['bush', 'voted', 'democrats'],
#  ['democrats', 'voter', 'war'],
#  ['bush', 'voter', 'democrats'],
#  ['bush', 'democrats', 'war'],
#  ['democrats', 'challenge', 'war'],
#  ['bush', 'challenge', 'democrats'],
#  ['bush', 'challenger', 'democrats'],
#  ['general', 'economy', 'house'],
#  ['general', 'economy', 'kerry'],
#  ['general', 'economy', 'media'],
#  ['general', 'economy', 'november'],
#  ['general', 'poll', 'economy'],
#  ['general', 'economy', 'polls'],
#  ['general', 'economy', 'republicans'],
#  ['general', 'economy', 'senate'],
#  ['general', 'economy', 'war'],
#  ['general', 'bush', 'economy'],
#  ['economy', 'media', 'house'],
#  ['poll', 'economy', 'house'],
#  ['economy', 'house', 'republicans'],
#  ['economy', 'house', 'senate'],
#  ['economy', 'house', 'war'],
#  ['bush', 'economy', 'house'],
#  ['poll', 'economy', 'kerry'],
#  ['economy', 'kerry', 'polls'],
#  ['economy', 'kerry', 'republicans'],
#  ['economy', 'kerry', 'war'],
#  ['bush', 'economy', 'kerry'],
#  ['bush', 'labor', 'economy'],
#  ['economy', 'media', 'polls'],
#  ['economy', 'media', 'republicans'],
#  ['economy', 'media', 'war'],
#  ['bush', 'economy', 'media'],
#  ['poll', 'economy', 'november'],
#  ['economy', 'november', 'republicans'],
#  ['bush', 'economy', 'november'],
#  ['poll', 'economy', 'polls'],
#  ['poll', 'economy', 'primary'],
#  ['poll', 'economy', 'republicans'],
#  ['poll', 'economy', 'war'],
#  ['poll', 'bush', 'economy'],
#  ['economy', 'polls', 'republicans'],
#  ['economy', 'polls', 'war'],
#  ['bush', 'economy', 'polls'],
#  ['bush', 'economy', 'primary'],
#  ['economy', 'senate', 'republicans'],
#  ['economy', 'republicans', 'war'],
#  ['bush', 'economy', 'republicans'],
#  ['economy', 'senate', 'war'],
#  ['bush', 'economy', 'senate'],
#  ['bush', 'economy', 'war'],
#  ['general', 'election', 'house'],
#  ['general', 'election', 'kerry'],
#  ['general', 'election', 'media'],
#  ['general', 'november', 'election'],
#  ['general', 'poll', 'election'],
#  ['general', 'election', 'polls'],
#  ['general', 'election', 'primary'],
#  ['general', 'election', 'republicans'],
#  ['general', 'election', 'senate'],
#  ['general', 'election', 'vote'],
#  ['general', 'election', 'voter'],
#  ['general', 'election', 'war'],
#  ['general', 'bush', 'election'],
#  ['kerry', 'election', 'house'],
#  ['election', 'media', 'house'],
#  ['november', 'election', 'house'],
#  ['poll', 'election', 'house'],
#  ['election', 'house', 'primary'],
#  ['election', 'house', 'republicans'],
#  ['election', 'house', 'senate'],
#  ['election', 'house', 'war'],
#  ['bush', 'election', 'house'],
#  ['kerry', 'election', 'media'],
#  ['kerry', 'poll', 'election'],
#  ['kerry', 'election', 'polls'],
#  ['kerry', 'election', 'primary'],
#  ['kerry', 'election', 'republicans'],
#  ['kerry', 'election', 'war'],
#  ['kerry', 'bush', 'election'],
#  ['poll', 'election', 'media'],
#  ['election', 'media', 'polls'],
#  ['election', 'media', 'republicans'],
#  ['election', 'media', 'war'],
#  ['bush', 'election', 'media'],
#  ['bush', 'november', 'election'],
#  ['poll', 'election', 'polls'],
#  ['poll', 'election', 'primary'],
#  ['poll', 'election', 'republicans'],
#  ['poll', 'election', 'senate'],
#  ['poll', 'election', 'war'],
#  ['poll', 'bush', 'election'],
#  ['election', 'polls', 'republicans'],
#  ['bush', 'election', 'polls'],
#  ['election', 'senate', 'primary'],
#  ['bush', 'election', 'primary'],
#  ['election', 'senate', 'republicans'],
#  ['election', 'republicans', 'war'],
#  ['bush', 'election', 'republicans'],
#  ['bush', 'election', 'senate'],
#  ['bush', 'election', 'vote'],
#  ['bush', 'election', 'voter'],
#  ['bush', 'election', 'war'],
#  ['general', 'electoral', 'house'],
#  ['general', 'electoral', 'kerry'],
#  ['general', 'electoral', 'media'],
#  ['general', 'poll', 'electoral'],
#  ['general', 'electoral', 'polls'],
#  ['general', 'electoral', 'primary'],
#  ['general', 'electoral', 'republicans'],
#  ['general', 'electoral', 'war'],
#  ['general', 'bush', 'electoral'],
#  ['electoral', 'kerry', 'house'],
#  ['poll', 'electoral', 'house'],
#  ['electoral', 'house', 'republicans'],
#  ['electoral', 'house', 'senate'],
#  ['electoral', 'bush', 'house'],
#  ['electoral', 'bush', 'kerry'],
#  ['electoral', 'bush', 'media'],
#  ['electoral', 'bush', 'november'],
#  ['poll', 'electoral', 'polls'],
#  ['poll', 'electoral', 'primary'],
#  ['poll', 'bush', 'electoral'],
#  ['electoral', 'bush', 'polls'],
#  ['electoral', 'bush', 'primary'],
#  ['electoral', 'bush', 'races'],
#  ['electoral', 'senate', 'republicans'],
#  ['electoral', 'bush', 'republicans'],
#  ['electoral', 'bush', 'senate'],
#  ['electoral', 'bush', 'war'],
#  ['general', 'bush', 'experience'],
#  ['experience', 'bush', 'media'],
#  ['experience', 'bush', 'war'],
#  ['general', 'house', 'governor'],
#  ['general', 'kerry', 'governor'],
#  ['general', 'media', 'governor'],
#  ['general', 'november', 'governor'],
#  ['general', 'poll', 'governor'],
#  ['general', 'polls', 'governor'],
#  ['general', 'primary', 'governor'],
#  ['general', 'races', 'governor'],
#  ['general', 'republicans', 'governor'],
#  ['general', 'senate', 'governor'],
#  ['general', 'governor', 'war'],
#  ['general', 'bush', 'governor'],
#  ['general', 'kerry', 'house'],
#  ['general', 'media', 'house'],
#  ['general', 'house', 'needed'],
#  ['general', 'november', 'house'],
#  ['general', 'poll', 'house'],
#  ['general', 'house', 'polls'],
#  ['general', 'house', 'primary'],
#  ['general', 'house', 'races'],
#  ['general', 'house', 'republicans'],
#  ['general', 'house', 'senate'],
#  ['general', 'ticket', 'house'],
#  ['general', 'house', 'voted'],
#  ['general', 'voter', 'house'],
#  ['general', 'house', 'war'],
#  ['general', 'bush', 'house'],
#  ['general', 'challenge', 'house'],
#  ['general', 'iraq', 'bush'],
#  ['general', 'kerry', 'john'],
#  ['general', 'bush', 'john'],
#  ['general', 'lead', 'kerry'],
#  ['general', 'kerry', 'media'],
#  ['general', 'november', 'kerry'],
#  ['general', 'poll', 'kerry'],
#  ['general', 'kerry', 'polls'],
#  ['general', 'president', 'kerry'],
#  ['general', 'kerry', 'primary'],
#  ['general', 'kerry', 'races'],
#  ['general', 'kerry', 'republicans'],
#  ['general', 'kerry', 'senate'],
#  ['general', 'kerry', 'split'],
#  ['general', 'kerry', 'time'],
#  ['general', 'kerry', 'vote'],
#  ['general', 'kerry', 'voted'],
#  ['general', 'kerry', 'voter'],
#  ['general', 'kerry', 'war'],
#  ['general', 'bush', 'kerry'],
#  ['general', 'kerry', 'campaign'],
#  ['general', 'kerry', 'challenger'],
#  ['general', 'labor', 'war'],
#  ['general', 'bush', 'labor'],
#  ['general', 'bush', 'lead'],
#  ['general', 'media', 'needed'],
#  ['general', 'november', 'media'],
#  ['general', 'poll', 'media'],
#  ['general', 'media', 'polls'],
#  ['general', 'media', 'primary'],
#  ['general', 'media', 'races'],
#  ['general', 'media', 'republicans'],
#  ['general', 'media', 'senate'],
#  ['general', 'ticket', 'media'],
#  ['general', 'voter', 'media'],
#  ['general', 'media', 'war'],
#  ['general', 'bush', 'media'],
#  ['general', 'bush', 'account'],
#  ['general', 'poll', 'needed'],
#  ['general', 'republicans', 'needed'],
#  ['general', 'senate', 'needed'],
#  ['general', 'needed', 'war'],
#  ['general', 'bush', 'needed'],
#  ['general', 'poll', 'november'],
#  ['general', 'november', 'polls'],
#  ['general', 'november', 'primary'],
#  ['general', 'november', 'races'],
#  ['general', 'november', 'republicans'],
#  ['general', 'november', 'senate'],
#  ['general', 'november', 'voter'],
#  ['general', 'november', 'war'],
#  ['general', 'bush', 'november'],
#  ['general', 'bush', 'people'],
#  ['general', 'bush', 'political'],
#  ['general', 'poll', 'polls'],
#  ['general', 'poll', 'primary'],
#  ['general', 'poll', 'races'],
#  ['general', 'poll', 'republicans'],
#  ['general', 'poll', 'senate'],
#  ['general', 'poll', 'split'],
#  ['general', 'poll', 'ticket'],
#  ['general', 'poll', 'vote'],
#  ['general', 'poll', 'voted'],
#  ['general', 'poll', 'voter'],
#  ['general', 'poll', 'war'],
#  ['general', 'bush', 'poll'],
#  ['general', 'poll', 'challenger'],
#  ['general', 'primary', 'polls'],
#  ['general', 'races', 'polls'],
#  ['general', 'republicans', 'polls'],
#  ['general', 'senate', 'polls'],
#  ['general', 'polls', 'split'],
#  ['general', 'polls', 'vote'],
#  ['general', 'voted', 'polls'],
#  ['general', 'voter', 'polls'],
#  ['general', 'polls', 'war'],
#  ['general', 'bush', 'polls'],
#  ['general', 'challenger', 'polls'],
#  ['general', 'bush', 'president'],
#  ['general', 'races', 'primary'],
#  ['general', 'primary', 'republicans'],
#  ['general', 'senate', 'primary'],
#  ['general', 'ticket', 'primary'],
#  ['general', 'primary', 'war'],
#  ['general', 'bush', 'primary'],
#  ['general', 'challenge', 'primary'],
#  ['general', 'races', 'republicans'],
#  ['general', 'races', 'senate'],
#  ['general', 'races', 'war'],
#  ['general', 'bush', 'races'],
#  ['general', 'bush', 'recommended'],
#  ['general', 'senate', 'republicans'],
#  ['general', 'republicans', 'split'],
#  ['general', 'ticket', 'republicans'],
#  ['general', 'republicans', 'vote'],
#  ['general', 'voted', 'republicans'],
#  ['general', 'voter', 'republicans'],
#  ['general', 'republicans', 'war'],
#  ['general', 'bush', 'republicans'],
#  ['general', 'challenge', 'republicans'],
#  ['general', 'challenger', 'republicans'],
#  ['general', 'bush', 'section'],
#  ['general', 'ticket', 'senate'],
#  ['general', 'voter', 'senate'],
#  ['general', 'senate', 'war'],
#  ['general', 'bush', 'senate'],
#  ['general', 'challenge', 'senate'],
#  ['general', 'split', 'war'],
#  ['general', 'bush', 'split'],
#  ['general', 'straight', 'war'],
#  ['general', 'bush', 'straight'],
#  ['general', 'ticket', 'war'],
#  ['general', 'bush', 'ticket'],
#  ['general', 'bush', 'time'],
#  ['general', 'bush', 'vote'],
#  ['general', 'voted', 'war'],
#  ['general', 'bush', 'voted'],
#  ['general', 'voter', 'war'],
#  ['general', 'bush', 'voter'],
#  ['general', 'bush', 'voters'],
#  ['general', 'bush', 'war'],
#  ['general', 'challenge', 'war'],
#  ['general', 'bush', 'bushs'],
#  ['general', 'bush', 'campaign'],
#  ['general', 'bush', 'challenge'],
#  ['general', 'bush', 'challenger'],
#  ['media', 'house', 'governor'],
#  ['poll', 'house', 'governor'],
#  ['house', 'polls', 'governor'],
#  ['house', 'primary', 'governor'],
#  ['house', 'races', 'governor'],
#  ['house', 'republicans', 'governor'],
#  ['house', 'senate', 'governor'],
#  ['governor', 'house', 'war'],
#  ['bush', 'house', 'governor'],
#  ['poll', 'kerry', 'governor'],
#  ['kerry', 'senate', 'governor'],
#  ['bush', 'kerry', 'governor'],
#  ['media', 'republicans', 'governor'],
#  ['media', 'senate', 'governor'],
#  ['governor', 'media', 'war'],
#  ['bush', 'media', 'governor'],
#  ['bush', 'november', 'governor'],
#  ['poll', 'polls', 'governor'],
#  ['poll', 'primary', 'governor'],
#  ['poll', 'races', 'governor'],
#  ['poll', 'republicans', 'governor'],
#  ['poll', 'senate', 'governor'],
#  ['poll', 'bush', 'governor'],
#  ['governor', 'polls', 'primary'],
#  ['governor', 'polls', 'republicans'],
#  ['senate', 'polls', 'governor'],
#  ['bush', 'polls', 'governor'],
#  ['races', 'primary', 'governor'],
#  ['governor', 'primary', 'republicans'],
#  ['governor', 'senate', 'primary'],
#  ['governor', 'primary', 'war'],
#  ['bush', 'primary', 'governor'],
#  ['races', 'republicans', 'governor'],
#  ['races', 'senate', 'governor'],
#  ['bush', 'races', 'governor'],
#  ['governor', 'senate', 'republicans'],
#  ['governor', 'republicans', 'war'],
#  ['bush', 'republicans', 'governor'],
#  ['challenge', 'republicans', 'governor'],
#  ['bush', 'senate', 'governor'],
#  ['challenge', 'senate', 'governor'],
#  ['governor', 'bush', 'war'],
#  ['bush', 'challenge', 'governor'],
#  ['kerry', 'media', 'house'],
#  ['kerry', 'november', 'house'],
#  ['poll', 'kerry', 'house'],
#  ['kerry', 'house', 'polls'],
#  ['kerry', 'house', 'primary'],
#  ['kerry', 'house', 'races'],
#  ['kerry', 'house', 'republicans'],
#  ['kerry', 'house', 'senate'],
#  ['kerry', 'house', 'war'],
#  ['bush', 'kerry', 'house'],
#  ['labor', 'media', 'house'],
#  ['labor', 'house', 'republicans'],
#  ['labor', 'house', 'senate'],
#  ['bush', 'labor', 'house'],
#  ['november', 'media', 'house'],
#  ['poll', 'media', 'house'],
#  ['media', 'house', 'polls'],
#  ['house', 'media', 'primary'],
#  ['house', 'media', 'races'],
#  ['house', 'media', 'republicans'],
#  ['house', 'media', 'senate'],
#  ['voter', 'media', 'house'],
#  ['media', 'house', 'war'],
#  ['bush', 'media', 'house'],
#  ['bush', 'account', 'house'],
#  ['house', 'primary', 'needed'],
#  ['house', 'republicans', 'needed'],
#  ['house', 'senate', 'needed'],
#  ['war', 'house', 'needed'],
#  ['bush', 'house', 'needed'],
#  ['poll', 'november', 'house'],
#  ['november', 'house', 'polls'],
#  ['november', 'house', 'primary'],
#  ['november', 'house', 'races'],
#  ['november', 'house', 'republicans'],
#  ['november', 'house', 'senate'],
#  ['november', 'voter', 'house'],
#  ['november', 'house', 'war'],
#  ['bush', 'november', 'house'],
#  ['poll', 'house', 'polls'],
#  ['poll', 'house', 'primary'],
#  ['poll', 'house', 'races'],
#  ['poll', 'house', 'republicans'],
#  ['poll', 'house', 'senate'],
#  ['poll', 'ticket', 'house'],
#  ['poll', 'house', 'voted'],
#  ['poll', 'voter', 'house'],
#  ['poll', 'house', 'war'],
#  ['poll', 'bush', 'house'],
#  ['poll', 'challenger', 'house'],
#  ['house', 'polls', 'primary'],
#  ['races', 'house', 'polls'],
#  ['house', 'polls', 'republicans'],
#  ['house', 'senate', 'polls'],
#  ['house', 'voter', 'polls'],
#  ['house', 'polls', 'war'],
#  ['bush', 'house', 'polls'],
#  ['races', 'house', 'primary'],
#  ['house', 'republicans', 'primary'],
#  ['house', 'senate', 'primary'],
#  ['house', 'voted', 'primary'],
#  ['house', 'primary', 'war'],
#  ['bush', 'house', 'primary'],
#  ['challenge', 'house', 'primary'],
#  ['challengers', 'house', 'primary'],
#  ['races', 'house', 'republicans'],
#  ['races', 'house', 'senate'],
#  ['house', 'races', 'war'],
#  ['bush', 'house', 'races'],
#  ['challenger', 'house', 'races'],
#  ['challengers', 'house', 'races'],
#  ['house', 'senate', 'republicans'],
#  ['ticket', 'house', 'republicans'],
#  ['house', 'voted', 'republicans'],
#  ['house', 'voter', 'republicans'],
#  ['house', 'republicans', 'war'],
#  ['bush', 'house', 'republicans'],
#  ['challenge', 'house', 'republicans'],
#  ['challenger', 'house', 'republicans'],
#  ['bush', 'select', 'house'],
#  ['house', 'senate', 'voted'],
#  ['house', 'voter', 'senate'],
#  ['house', 'senate', 'war'],
#  ['bush', 'house', 'senate'],
#  ['challenge', 'house', 'senate'],
#  ['bush', 'house', 'split'],
#  ['bush', 'straight', 'house'],
#  ['bush', 'ticket', 'house'],
#  ['bush', 'house', 'vote'],
#  ['house', 'voted', 'war'],
#  ['bush', 'house', 'voted'],
#  ['voter', 'house', 'war'],
#  ['bush', 'voter', 'house'],
#  ['bush', 'house', 'war'],
#  ['challenge', 'house', 'war'],
#  ['bush', 'challenge', 'house'],
#  ...]
