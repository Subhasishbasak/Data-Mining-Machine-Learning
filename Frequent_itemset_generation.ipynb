# %% [markdown]
# # Data Mining Machine Learning/Assignment_1<br>MDS201803 and MDS201811

# %% [markdown]
# ### Description of the code to find frequent itemsets using Apriori algorithm

# %% [markdown]
# For each collection we are provided with 2 datasets viz. docword and vocab.<br>
# we follow these steps:
# - We store the 2 datasets using PANDAS dataframe as docword and vocab
# - From the docword dataframe we discard the first 3 header rows which cntain information about the dataset
# - Next we split the remaining portion of the docword dataset into 3 parts consisting docID, wordID and count
# - After that we create a dictionary to store the word_id's corresponding to each doc_id by iterating over the rows of the truncated dataset
# - Using this dictionary we contruct a array of arrays which stores the word_ids corresponding to each document
# - Now, to perform apriori we use the **"mlxtend"** library
# - the apriori function under mlxtend requires a Matrix and minimum support (user input F) as input. The matrix has the word_ids as columns and doc_ids as rows. Each element of the matrix stores either True or False according as the word_id is present in the doc_id. This matrix turns out to be a sparse matrix
# - Then we filter the frequent itemsets w.r.t the size of the set (user input K).
# - Next we create another dictionary to store the words corresponding to each word_id, using the vocab dataset.
# - Using this dictionary we map each word_id in the fequent itemset to the original word, which gives the required answer.

# %%
def Frequent_itemset(n,K,F):
    import pandas as pd
    import time
    from mlxtend.preprocessing import TransactionEncoder
    from mlxtend.frequent_patterns import apriori
    start = time.time()
    docword = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/bag-of-words/docword."+n+".txt.gz",header=None)
    vocab = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/bag-of-words/vocab."+n+".txt",header=None)
    trunc = docword[3:]        #truncates the Docword to remove the first 3 header line
    docword_splitted = pd.DataFrame(trunc[0].str.split(" ", n = 2, expand = True))    #Splits the truncated Docword into a data frame of 3 columns storing D,W,NNZ
    docword_splitted.columns = ['docID', 'wordID', 'count']      # Renames the column names of the splitted dataframe
    dict_1={}                  #creates a dictionary 
    for index,row in docword_splitted.iterrows():           # iterates over kos_splitted to create a dictionary for document ID's to store word ID's corresponding each document
      try:
        dict_1[row['docID']].append(row['wordID'])
      except Exception:
        dict_1[row['docID']] = []
        dict_1[row['docID']].append(row['wordID'])
    array = []                                   #creates an empty array
    for i in range(1,int(docword[0][0])+1):      #creates an array of arrays containing all the inique word_id's of the documents
        array.append(dict_1[str(i)])    
    Sp = TransactionEncoder()        
    Sp_array = Sp.fit(array).transform(array)
    Sp_matrix = pd.DataFrame(Sp_array, columns=Sp.columns_)   #creates the sparse matrix with columns as word_id & rows as doc_id
    ans = apriori(Sp_matrix, min_support=F)
    d={}                                             
    for index,row in vocab.iterrows():
        d[index] = row[0]                            #creates dictionary to store words corresponding to word_id's
    itemset = []                                      
    for i in ans.itemsets:
        if len(i) == K:
            itemset.append(i)                        #filtering the frequent itemsets w.r.t set size
    a = [list(x) for x in itemset]
    for i in a:
        for j in range(0,K):
            i[j] = d[i[j]]                           #replacing word_id's by the words itself
    print(a)        
    end = time.time()
    print("The running time is : ",end-start)        #prints the running time of the code

# %%
Frequent_itemset("kos",3,0.1)
# Out:
# [['airplane', 'brad', 'boycott'], ['disregard', 'airplane', 'boycott'], ['airplane', 'expert', 'boycott'], ['injured', 'airplane', 'boycott'], ['airplane', 'movements', 'boycott'], ['airplane', 'northup', 'boycott'], ['airplane', 'portrayed', 'boycott'], ['airplane', 'recruiting', 'boycott'], ['weapons', 'airplane', 'boycott'], ['disregard', 'airplane', 'brad'], ['airplane', 'brad', 'expert'], ['injured', 'airplane', 'brad'], ['airplane', 'portrayed', 'brad'], ['airplane', 'brad', 'recruiting'], ['weapons', 'airplane', 'brad'], ['disregard', 'airplane', 'golden'], ['disregard', 'airplane', 'injured'], ['disregard', 'airplane', 'movements'], ['disregard', 'airplane', 'moves'], ['disregard', 'airplane', 'portrayed'], ['disregard', 'tomorrows', 'airplane'], ['disregard', 'weapons', 'airplane'], ['weapons', 'airplane', 'expert'], ['weapons', 'airplane', 'golden'], ['injured', 'airplane', 'movements'], ['injured', 'airplane', 'northup'], ['injured', 'airplane', 'recruiting'], ['injured', 'weapons', 'airplane'], ['moves', 'airplane', 'movements'], ['weapons', 'airplane', 'movements'], ['moves', 'weapons', 'airplane'], ['weapons', 'airplane', 'portrayed'], ['weapons', 'airplane', 'recruiting'], ['tomorrows', 'weapons', 'airplane'], ['weapons', 'boycott', 'armstrong'], ['disregard', 'weapons', 'armstrong'], ['tomorrows', 'armstrong', 'expert'], ['weapons', 'armstrong', 'expert'], ['injured', 'weapons', 'armstrong'], ['weapons', 'portrayed', 'armstrong'], ['tomorrows', 'weapons', 'armstrong'], ['banned', 'boycott', 'brad'], ['banned', 'disregard', 'boycott'], ['banned', 'boycott', 'injured'], ['banned', 'boycott', 'portrayed'], ['banned', 'tomorrows', 'boycott'], ['banned', 'weapons', 'boycott'], ['banned', 'brad', 'expert'], ['banned', 'portrayed', 'brad'], ['banned', 'tomorrows', 'brad'], ['banned', 'weapons', 'brad'], ['banned', 'clever', 'weapons'], ['banned', 'disregard', 'expert'], ['banned', 'disregard', 'injured'], ['banned', 'disregard', 'portrayed'], ['banned', 'tomorrows', 'disregard'], ['banned', 'disregard', 'weapons'], ['banned', 'portrayed', 'expert'], ['banned', 'recruiting', 'expert'], ['banned', 'tomorrows', 'expert'], ['banned', 'weapons', 'expert'], ['banned', 'weapons', 'golden'], ['banned', 'tomorrows', 'injured'], ['banned', 'weapons', 'injured'], ['banned', 'tomorrows', 'movements'], ['banned', 'weapons', 'movements'], ['banned', 'tomorrows', 'portrayed'], ['banned', 'weapons', 'portrayed'], ['banned', 'weapons', 'recruiting'], ['banned', 'tomorrows', 'weapons'], ['boycott', 'brad', 'bed'], ['weapons', 'boycott', 'bed'], ['weapons', 'brad', 'bed'], ['weapons', 'portrayed', 'bed'], ['boycott', 'golden', 'blamed'], ['boycott', 'northup', 'blamed'], ['bowers', 'boycott', 'brad'], ['disregard', 'bowers', 'boycott'], ['bowers', 'boycott', 'dozens'], ['bowers', 'boycott', 'expert'], ['bowers', 'boycott', 'golden'], ['injured', 'bowers', 'boycott'], ['leaves', 'bowers', 'boycott'], ['bowers', 'boycott', 'movements'], ['moves', 'bowers', 'boycott'], ['bowers', 'boycott', 'northup'], ['bowers', 'boycott', 'owners'], ['bowers', 'boycott', 'portrayed'], ['bowers', 'boycott', 'recruiting'], ['bowers', 'boycott', 'tomorrows'], ['bowers', 'weapons', 'boycott'], ['disregard', 'bowers', 'brad'], ['bowers', 'brad', 'dozens'], ['bowers', 'brad', 'expert'], ['bowers', 'golden', 'brad'], ['injured', 'bowers', 'brad'], ['movements', 'bowers', 'brad'], ['moves', 'bowers', 'brad'], ['bowers', 'northup', 'brad'], ['bowers', 'owners', 'brad'], ['bowers', 'portrayed', 'brad'], ['bowers', 'recruiting', 'brad'], ['bowers', 'tomorrows', 'brad'], ['bowers', 'weapons', 'brad'], ['disregard', 'bowers', 'expert'], ['disregard', 'bowers', 'golden'], ['disregard', 'bowers', 'injured'], ['disregard', 'bowers', 'leaves'], ['disregard', 'bowers', 'movements'], ['disregard', 'bowers', 'moves'], ['disregard', 'bowers', 'northup'], ['disregard', 'bowers', 'portrayed'], ['disregard', 'bowers', 'recruiting'], ['disregard', 'bowers', 'tomorrows'], ['disre ...
# The running time is :  69.45359396934509

# %%
Frequent_itemset("enron",1,0.09)
# Out:
# [['abel'], ['adobe'], ['airway'], ['alkaseltzer'], ['annexes'], ['auburn'], ['barrett'], ['battlefield'], ['bayless'], ['boasted'], ['calderon'], ['calf'], ['conferences'], ['contend'], ['crux'], ['decided'], ['degrade'], ['denied'], ['disabled'], ['discounted'], ['elf'], ['emergis'], ['enlarge'], ['enlist'], ['espn'], ['famed'], ['floated'], ['forged'], ['formas'], ['freeforall'], ['gaillard'], ['gisb'], ['goldstein'], ['gooden'], ['gri'], ['hillcrest'], ['hilliard'], ['img'], ['imperial'], ['infomation'], ['koepke'], ['kw3000tm'], ['kym'], ['l999'], ['maturing'], ['misha'], ['missile'], ['munson'], ['newenergy'], ['newer'], ['projectwe'], ['ram'], ['redwater'], ['rejoin'], ['rising'], ['scenario'], ['sechrest'], ['seismic'], ['shutting'], ['sjbc'], ['slab'], ['specialinterest'], ['speculating'], ['stages'], ['stateroom'], ['tanked'], ['time300'], ['unbundle'], ['undeliverable'], ['wilcox'], ['yasir'], ['zhang']]
# The running time is :  568.1927163600922

# %%
Frequent_itemset("nips",2,0.7)
# Out:
# [['black', 'abandonment'], ['format', 'abandonment'], ['ira', 'abandonment'], ['abandonment', 'lancaster'], ['murphy', 'abandonment'], ['abandonment', 'naturalistic'], ['nll', 'abandonment'], ['peaked', 'abandonment'], ['abandonment', 'recon'], ['revolution', 'abandonment'], ['rfm', 'abandonment'], ['sakai', 'abandonment'], ['abandonment', 'suited'], ['trained', 'abandonment'], ['union', 'abandonment'], ['ira', 'black'], ['black', 'lancaster'], ['murphy', 'black'], ['black', 'naturalistic'], ['nll', 'black'], ['black', 'recon'], ['revolution', 'black'], ['rfm', 'black'], ['sakai', 'black'], ['black', 'suited'], ['trained', 'black'], ['union', 'black'], ['ira', 'con'], ['ira', 'dimensionless'], ['dimensionless', 'lancaster'], ['dimensionless', 'rfm'], ['trained', 'dimensionless'], ['union', 'dimensionless'], ['format', 'ira'], ['format', 'lancaster'], ['format', 'rfm'], ['trained', 'format'], ['format', 'union'], ['hid', 'ira'], ['trained', 'hid'], ['ira', 'khz'], ['ira', 'lancaster'], ['ira', 'murphy'], ['ira', 'naturalistic'], ['ira', 'nll'], ['ira', 'partial'], ['ira', 'peaked'], ['ira', 'recon'], ['ira', 'revolution'], ['ira', 'rfm'], ['sakai', 'ira'], ['ira', 'semble'], ['ira', 'shaded'], ['shrinkage', 'ira'], ['ira', 'sides'], ['ira', 'standpoint'], ['ira', 'suited'], ['ira', 'summarizes'], ['trained', 'ira'], ['union', 'ira'], ['murphy', 'lancaster'], ['naturalistic', 'lancaster'], ['nll', 'lancaster'], ['peaked', 'lancaster'], ['recon', 'lancaster'], ['revolution', 'lancaster'], ['rfm', 'lancaster'], ['sakai', 'lancaster'], ['suited', 'lancaster'], ['trained', 'lancaster'], ['union', 'lancaster'], ['murphy', 'nll'], ['murphy', 'revolution'], ['murphy', 'rfm'], ['sakai', 'murphy'], ['trained', 'murphy'], ['union', 'murphy'], ['nll', 'naturalistic'], ['revolution', 'naturalistic'], ['rfm', 'naturalistic'], ['sakai', 'naturalistic'], ['trained', 'naturalistic'], ['union', 'naturalistic'], ['nll', 'recon'], ['nll', 'revolution'], ['nll', 'rfm'], ['sakai', 'nll'], ['nll', 'suited'], ['trained', 'nll'], ['union', 'nll'], ['peaked', 'rfm'], ['trained', 'peaked'], ['union', 'peaked'], ['revolution', 'recon'], ['rfm', 'recon'], ['sakai', 'recon'], ['trained', 'recon'], ['union', 'recon'], ['rfm', 'revolution'], ['sakai', 'revolution'], ['revolution', 'suited'], ['trained', 'revolution'], ['union', 'revolution'], ['sakai', 'rfm'], ['rfm', 'suited'], ['trained', 'rfm'], ['union', 'rfm'], ['sakai', 'suited'], ['sakai', 'trained'], ['sakai', 'union'], ['trained', 'semble'], ['union', 'semble'], ['trained', 'shrinkage'], ['shrinkage', 'union'], ['trained', 'suited'], ['union', 'suited'], ['trained', 'union']]
# The running time is :  110.50045943260193
